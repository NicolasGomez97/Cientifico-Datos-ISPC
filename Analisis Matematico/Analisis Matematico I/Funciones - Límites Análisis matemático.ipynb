# %% [markdown]
# # Capitulo 1
#
# ## Redimento de python 3: Funciones
#
# Sintaxis basica

# %%
def nombre_funcion(argumentos):
    # instruccciones
    pass

# %%
nombre_funcion(5)

# %% [markdown]
# #### Funcion:$y - f(x)$
#
# ### $y = \sin(x) + \cos(X)$

# %%
import math as m

def y(x):
    return m.sin(x) + m.cos(x)

print(y(m.pi/2))
# Out:
# 1.0

# %% [markdown]
# #### Ecuacion de la recta: $y=mx + b$

# %%
def pendiente(x1,y1,x2,y2):
    if x1-x2 ==  0:
        pass
    else:
        return (y2-y1)/(x2-x1)
def ecuacion_recta(m, x1, y1):
    b = -x1*m + y1
    print("y =",m,"x + b \n",b)

# %%
m = pendiente(3,2,1,1)
print(m)
ecuacion_recta(m,1,1)
# Out:
# 0.5
# y = 0.5 x + b
#  0.5

# %%
import numpy as np  

#defino la función f que:
#recibe como parámetro o variable de entrada x y
#retorna la raiz cuadrada de la suma de x mas 2
def f(x):
    return np.sqrt(x + 2)

# %%
# Un comentario se definie anteponiendo el símbolo #
# importo la librería numpy
import numpy as np  

#defino la función f que:
#recibe como parámetro o variable de entrada x y
#retorna la raiz cuadrada de la suma de x mas 
def f(x):
    #return ((x^3 + 5*x + 6)/(x^2-1))
    return ((np.power(x,3) + 5*x + 6)/(np.power(x,2)-4))

#Defino un vector con 500 valores que tomará x durante la ejecución de f(x)
x = np.linspace(-10, 10, 500)
#print(x)
#asigno a y el resultado de f(x)
y = f(x)
#muestro los valores calculados (con cada x) de cada y
#y

# %matplotlib inline

import matplotlib.pyplot as plt

def move_spines():
    """Esta funcion divide pone al eje y en el valor 
    0 de x para dividir claramente los valores positivos y
    negativos."""
    fix, ax = plt.subplots(figsize=(15,10))
    for spine in ["left", "bottom"]:
        ax.spines[spine].set_position("zero")
    
    for spine in ["right", "top"]:
        ax.spines[spine].set_color("none")
    
    return ax

#x = np.linspace(-10, 10, num=500)

ax = move_spines()
ax.grid()
ax.plot(x, f(x))
plt.title(r"Grafico de $f(x)=\{x^3 + 5x + 2}$")
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()

# %%
#Defino un vector con 6 valores que tomará x durante la ejecución de f(x)
x = np.array([-2, -1, 0, 2, 4, 6])  # Creando el vector de valores de x
#asigno a y el resultado de f(x)
y = f(x)
#muestro los valores calculados (con cada x) de cada y
y
# Out:
# C:\Users\Nicol\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.
# array([  -inf, -0.   , -1.5  ,    inf,  7.5  ,  7.875])

# %%
#importo la librería pandas con alias pd
import pandas as pd
#asigno a tabla un Dataframe (ya veremos que es) con los valores de cada x e y correspondiente en las filas
tabla = pd.DataFrame( list(zip(x, y)), columns=['x', 'f(x)'] )
tabla
# Out:
#    x   f(x)
# 0 -2   -inf
# 1 -1 -0.000
# 2  0 -1.500
# 3  2    inf
# 4  4  7.500
# 5  6  7.875

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

def move_spines():
    """Esta funcion divide pone al eje y en el valor 
    0 de x para dividir claramente los valores positivos y
    negativos."""
    fix, ax = plt.subplots(figsize=(15,10))
    for spine in ["left", "bottom"]:
        ax.spines[spine].set_position("zero")
    
    for spine in ["right", "top"]:
        ax.spines[spine].set_color("none")
    
    return ax

x = np.linspace(-2, 6, num=30)

ax = move_spines()
ax.grid()
ax.plot(x, f(x))
plt.title(r"Grafico de $f(x)=\sqrt{x + 2}$")
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()
# Out:
# C:\Users\Nicol\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ## Hora de hacer ejercicios de funciones...

# %% [markdown]
# y = $−2x +1$
# y = a.x +b

# %%
# Un comentario se definie anteponiendo el símbolo #
# importo la librería numpy
import numpy as np  

#defino la función f que:
#recibe como parámetro o variable de entrada x y
#retorna la raiz cuadrada de la suma de x mas 
def f(x):
    #return ((x^3 + 5*x + 6)/(x^2-1))
    return (2*x -3)

#Defino un vector con 6 valores que tomará x durante la ejecución de f(x)
x = np.linspace(-10, 10, 6)
#print(x)
#asigno a y el resultado de f(x)
y = f(x)
print(x,y)
#muestro los valores calculados (con cada x) de cada y
#y

# %matplotlib inline

import matplotlib.pyplot as plt

def move_spines():
    """Esta funcion divide pone al eje y en el valor 
    0 de x para dividir claramente los valores positivos y
    negativos."""
    fix, ax = plt.subplots(figsize=(15,10))
    for spine in ["left", "bottom"]:
        ax.spines[spine].set_position("zero")
    
    for spine in ["right", "top"]:
        ax.spines[spine].set_color("none")
    
    return ax

#x = np.linspace(-10, 10, num=500)

ax = move_spines()
ax.grid()
ax.plot(x, f(x))
plt.title(r"Grafico de $f(x)=\{2*x -3}$")
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()
# Out:
# [-10.  -6.  -2.   2.   6.  10.] [-23. -15.  -7.   1.   9.  17.]

# %% [markdown]
# $y = (-1/2)*x+4$

# %%
# Un comentario se definie anteponiendo el símbolo #
# importo la librería numpy
import numpy as np  

#defino la función f que:
#recibe como parámetro o variable de entrada x y
#retorna la raiz cuadrada de la suma de x mas 
def f(x):
    #return ((x^3 + 5*x + 6)/(x^2-1))
    return ((-1/2)*x + 4)

#Defino un vector con 6 valores que tomará x durante la ejecución de f(x)
x = np.linspace(-10, 10, 6)
#print(x)
#asigno a y el resultado de f(x)
y = f(x)
print(x,y)
#muestro los valores calculados (con cada x) de cada y
#y

# %matplotlib inline

import matplotlib.pyplot as plt

def move_spines():
    """Esta funcion divide pone al eje y en el valor 
    0 de x para dividir claramente los valores positivos y
    negativos."""
    fix, ax = plt.subplots(figsize=(15,10))
    for spine in ["left", "bottom"]:
        ax.spines[spine].set_position("zero")
    
    for spine in ["right", "top"]:
        ax.spines[spine].set_color("none")
    
    return ax

#x = np.linspace(-10, 10, num=500)

ax = move_spines()
ax.grid()
ax.plot(x, f(x))
plt.title(r"Grafico de $f(x)=\{(-1/2)*x + 4}$")
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()
# Out:
# [-10.  -6.  -2.   2.   6.  10.] [ 9.  7.  5.  3.  1. -1.]

# %% [markdown]
# $2x -4y =1$

# %%
# Un comentario se definie anteponiendo el símbolo #
# importo la librería numpy
import numpy as np  

#defino la función f que:
#recibe como parámetro o variable de entrada x y
#retorna la raiz cuadrada de la suma de x mas 
#def f(x):
    #return ((x^3 + 5*x + 6)/(x^2-1))
    #return ((2*x-4*y)

#Defino un vector con 6 valores que tomará x durante la ejecución de f(x)
x = # Un comentario se definie anteponiendo el símbolo #
# importo la librería numpy
import numpy as np  

#defino la función f que:
#recibe como parámetro o variable de entrada x y
#retorna la raiz cuadrada de la suma de x mas 
def f(x):
    #return ((x^3 + 5*x + 6)/(x^2-1))
    return ((-1/2)*x + 4)

#Defino un vector con 6 valores que tomará x durante la ejecución de f(x)
x = np.linspace(-10, 10, 6)
y = np.linspace(-10, 10, 6)
#print(x)
#asigno a y el resultado de f(x)
print(x,y)
#muestro los valores calculados (con cada x) de cada y
#y

# %matplotlib inline

import matplotlib.pyplot as plt

def move_spines():
    """Esta funcion divide pone al eje y en el valor 
    0 de x para dividir claramente los valores positivos y
    negativos."""
    fix, ax = plt.subplots(figsize=(15,10))
    for spine in ["left", "bottom"]:
        ax.spines[spine].set_position("zero")
    
    for spine in ["right", "top"]:
        ax.spines[spine].set_color("none")
    
    return ax

#x = np.linspace(-10, 10, num=500)

ax = move_spines()
ax.grid()
ax.plot(x, f(x))
plt.title(r"Grafico de $f(x)=\{(-1/2)*x + 4}$")
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()

y = 
#print(x)
#asigno a y el resultado de f(x)
y = f(x)
print(x,y)
#muestro los valores calculados (con cada x) de cada y
#y

# %matplotlib inline

import matplotlib.pyplot as plt

def move_spines():
    """Esta funcion divide pone al eje y en el valor 
    0 de x para dividir claramente los valores positivos y
    negativos."""
    fix, ax = plt.subplots(figsize=(15,10))
    for spine in ["left", "bottom"]:
        ax.spines[spine].set_position("zero")
    
    for spine in ["right", "top"]:
        ax.spines[spine].set_color("none")
    
    return ax

#x = np.linspace(-10, 10, num=500)

ax = move_spines()
ax.grid()
ax.plot(x, f(x))
plt.title(r"Grafico de $f(x)=\{(-1/2)*x + 4}$")
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()
# Out:
#   File "<ipython-input-6-1f3edafd248c>", line 13
#     x = np.linspace(-10, 10, 6)
#     ^
# SyntaxError: invalid syntax

# %%
eval(2*x+10=12)
# Out:
#   File "<ipython-input-13-289f6f2c14b6>", line 1
#     eval(2*x+10=12)
#         ^
# SyntaxError: keyword can't be an expression

# %%
# Un comentario se definie anteponiendo el símbolo #
# importo la librería numpy
import numpy as np  

#defino la función f que:
#recibe como parámetro o variable de entrada x y
#retorna la raiz cuadrada de la suma de x mas 2
def f(x):
    #return ((x^3 + 5*x + 6)/(x^2-1))
    return (np.exp(20*x))

#Defino un vector con 6 valores que tomará x durante la ejecución de f(x)
#x = np.linspace(-10, 10, 500)
x=np.array([i/100. for i in range(100)])
#print(x)
#asigno a y el resultado de f(x)
y = f(x)
#muestro los valores calculados (con cada x) de cada y
#y

# %matplotlib inline

import matplotlib.pyplot as plt

def move_spines():
    """Esta funcion divide pone al eje y en el valor 
    0 de x para dividir claramente los valores positivos y
    negativos."""
    fix, ax = plt.subplots(figsize=(15,10))
    for spine in ["left", "bottom"]:
        ax.spines[spine].set_position("zero")
    
    for spine in ["right", "top"]:
        ax.spines[spine].set_color("none")
    
    return ax

#x = np.linspace(-10, 10, num=500)

ax = move_spines()
ax.grid()
ax.plot(x, f(x))
plt.title(r"Grafico de $f(x)=np.exp(20*x)}$")
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()

# %%
import numpy as npy
import matplotlib.pyplot as plt
x=npy.array([i/100. for i in range(100)])
y=npy.exp(20*x)
plt.figure(figsize=(15,10))
plt.semilogy(x, y)
plt.show()

# %%
# Un comentario se definie anteponiendo el símbolo #
# importo la librería numpy
import numpy as np  

#defino la función f que:
#recibe como parámetro o variable de entrada x y
#retorna la raiz cuadrada de la suma de x mas 2
def f(x):
    #return ((x^3 + 5*x + 6)/(x^2-1))
    return (np.log(20*x))

#Defino un vector con 6 valores que tomará x durante la ejecución de f(x)
#x = np.linspace(-10, 10, 500)
x=np.array([i/100. for i in range(100)])
#print(x)
#asigno a y el resultado de f(x)
y = f(x)
#muestro los valores calculados (con cada x) de cada y
#y

# %matplotlib inline

import matplotlib.pyplot as plt

def move_spines():
    """Esta funcion divide pone al eje y en el valor 
    0 de x para dividir claramente los valores positivos y
    negativos."""
    fix, ax = plt.subplots(figsize=(15,10))
    for spine in ["left", "bottom"]:
        ax.spines[spine].set_position("zero")
    
    for spine in ["right", "top"]:
        ax.spines[spine].set_color("none")
    
    return ax

#x = np.linspace(-10, 10, num=500)

ax = move_spines()
ax.grid()
ax.plot(x, f(x))
plt.title(r"Grafico de $f(x)=np.log(20*x)}$")
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()
# Out:
# C:\Users\Nicol\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in log
#   # Remove the CWD from sys.path while we load stuff.

# %%
import pandas as pd
x = np.linspace(0, 10 * np.pi, 500)
sinewave1 = np.sin(x) + np.random.normal(scale=0.051, size=len(x))
df = pd.DataFrame(sinewave1)
df.columns=['sine1']
df['ret sine1']=df['sine1'].pct_change()

# %%
x = np.linspace(0, 10 * np.pi, 500)
sinewave2 = np.sin(x+0.25) + np.random.normal(scale=0.061, size=len(x))
df['sine2'] = sinewave2
df['ret sine2']=df['sine2'].pct_change()

# %%
x = df.index
y1 = df['sine1']
y2 = df['sine2']

# Plot Line1 (Left Y Axis)
fig, ax1 = plt.subplots(1,1,figsize=(16,10), dpi= 120)
ax1.plot(x, y1, color='tab:red')
#plt.hlines(y=0.05, xmin=0, xmax=len(adf_gbpusd_gbpjpy['ADF']), linewidth=2, color='r',label='LIM 0.05 ADF')
# Plot Line2 (Right Y Axis)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.plot(x, y2, color='tab:blue')
'''
# Plot Line2 (Right Y Axis)
ax3 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax3.plot(x, y3, color='tab:green')
# Plot Line2 (Right Y Axis)
ax4 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax4.plot(x, y4, color='tab:green')
'''
# Just Decorations!! -------------------
# ax1 (left y axis)
ax1.set_xlabel('serie1', fontsize=20)
ax1.set_ylabel('seno', color='tab:red', fontsize=20)
ax1.tick_params(axis='y', rotation=0, labelcolor='tab:red' )

# ax2 (right Y axis)
ax2.set_ylabel("# seno2d", color='tab:blue', fontsize=20)
ax2.tick_params(axis='y', labelcolor='tab:blue')
ax2.set_title("Prueba Trading", fontsize=20)
ax2.set_xticks(np.arange(0, len(x), 60))
ax2.set_xticklabels(x[::60], rotation=90, fontdict={'fontsize':10})
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
x = np.linspace(0, 9, 100)
plt.plot(
    x, np.exp(x / 3) * np.cos(x) + 10 * np.sin(3 * x), 
    x, x ** 2 / 4
)
plt.show()

# %%
# !pip install sympy
# Out:
# Requirement already satisfied: sympy in c:\users\nicol\anaconda3\lib\site-packages (1.4)
# Requirement already satisfied: mpmath>=0.19 in c:\users\nicol\anaconda3\lib\site-packages (from sympy) (1.1.0)

# %%
from sympy import Symbol, solve
x=Symbol("x") 
x+x+1
# Out:
# 2*x + 1

# %%
x=Symbol("x") 
y=Symbol("y") 
ecua1=2*x+3*y-6 
ecua2=3*x+2*y-12 
solve((ecua1,ecua2),dict=True)
# Out:
# [{x: 24/5, y: -6/5}]

# %%
y = Symbol('x')
eq1 = x**2 - 5*x + 6
sol = solve(eq1)
sol
# Out:
# [2, 3]

# %% [markdown]
# # Límites
#
# Uno de los conceptos más importantes dentro del [Cálculo](https://es.wikipedia.org/wiki/C%C3%A1lculo_infinitesimal) es el concepto de *[Límite](https://es.wikipedia.org/wiki/L%C3%ADmite_matem%C3%A1tico)*. Se dice que una función $f$ tiende hacia el *[Límite](https://es.wikipedia.org/wiki/L%C3%ADmite_matem%C3%A1tico)* $l$ cerca de $a$, si se puede hacer que $f(x)$ este tan próxima como queramos de $l$, haciendo que $x$ esté suficientemente cerca de $a$, pero siendo distinta de $a$. Así por ejemplo si analizamos la función $f(x) = x^2 - x + 2$, para los valores cercanos a 2, podríamos ver los siguientes resultados.

# %%
# <!-- collapse=True -->
def f(x):
    return x**2 - x + 2

x = np.array([1, 1.5, 1.9, 1.95, 1.99, 1.999, 2.001, 2.05, 2.1, 2.2, 2.5, 3 ])
y = f(x)
tabla = pd.DataFrame(list(zip(x, y)), columns=['x', 'f(x)'])
tabla
# Out:
#         x      f(x)
# 0   1.000  2.000000
# 1   1.500  2.750000
# 2   1.900  3.710000
# 3   1.950  3.852500
# 4   1.990  3.970100
# 5   1.999  3.997001
# 6   2.001  4.003001
# 7   2.050  4.152500
# 8   2.100  4.310000
# 9   2.200  4.640000
# 10  2.500  5.750000
# 11  3.000  8.000000

# %% [markdown]
# de acuerdo con esta tabla, podemos ver que a medida que hacemos al valor de $x$ cercano a 2, vemos que $f(x)$ se hace muy cercana a 4. Incluso podríamos hacer a $f(x)$ tan cercana como queramos a 4, haciendo que $x$ este lo suficientemente cerca de 2. Por lo tanto, podemos expresar esta propiedad diciendo que el *"[Límite](https://es.wikipedia.org/wiki/L%C3%ADmite_matem%C3%A1tico) de la función $f(x) = x^2 - x + 2$ cuando $x$ se acerca a 2 es igual a 4."* y lo podemos representar con la siguiente notación:
#
# $$\lim_{x\to 2} \left(x^2 -x + 2\right) = 4$$
#
# Gráficamente lo podemos ver del siguiente modo.

# %%
# <!-- collapse=True -->
x = np.linspace(-2, 4, num=30)

ax = move_spines()
ax.grid()
ax.plot(x, f(x))
ax.scatter(2, 4, label="limite cuando x tiende a 2", color='r')
plt.legend()
plt.title(r"Grafico de $f(x)=x^2 -x + 2$")
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()

# %% [markdown]
# ### Las leyes de los límites
#
# Calcular el valor exacto de los *[Límites](https://es.wikipedia.org/wiki/L%C3%ADmite_matem%C3%A1tico)* muchas veces no suele tan fácil como reemplazar el valor de $a$ en $f(x)$. Es por esto que es importante conocer algunas propiedades de los *[Límites](https://es.wikipedia.org/wiki/L%C3%ADmite_matem%C3%A1tico)*, ellas son:
#
# 1. **Ley de la suma:** El límite de la suma de dos funciones es la suma de sus límites.
# 2. **Ley de la diferencia:** El límite de la diferencia de dos funciones es la diferencia de sus límites.
# 3. **Ley del producto:** El límite del producto de dos funciones es el producto de sus límites.
# 4. **ley del múltiplo constante:** El límite de una constante por una función es la constante por el límite de la función.
# 5. **Ley del cociente:** El límite del cociente de dos funciones es el cociente de sus límites, siempre que el límite del denominador sea diferente de *cero*.
#
# Es decir que si tenemos a la constante $C$ y a los límites $\lim_{x\to a} f(x)$ y $\lim_{x\to a} g(x)$. Entonces podemos expresar estas propiedades matemáticamente de la siguiente forma:
#
# 1- **Ley de la suma:** $\lim_{x\to a} [f(x) + g(x)] = \lim_{x\to a} f(x) + \lim_{x\to a} g(x)$.
#
#
# 2- **Ley de la diferencia:** $\lim_{x\to a} [f(x) - g(x)] = \lim_{x\to a} f(x) - \lim_{x\to a} g(x)$.
#
#
# 3- **Ley del producto:** $\lim_{x\to a} [f(x) \cdot g(x)] = \lim_{x\to a} f(x) \cdot \lim_{x\to a} g(x)$.
#
#
# 4- **ley del multiplo constante:** $\lim_{x\to a} [C \cdot f(x)] = C \cdot \lim_{x\to a} f(x)$.
#
#
# 5- **Ley del cociente:** $\lim_{x\to a} \left[\frac{f(x)}{g(x)}\right] = \frac{\lim_{x\to a} f(x)}{\lim_{x\to a} g(x)}$, si $\lim_{x\to a} g(x) \ne 0$.
#
#
# ### Calculando Límites con Python
#
# Con [Python](https://www.python.org/), podemos resolver *[Límites](https://es.wikipedia.org/wiki/L%C3%ADmite_matem%C3%A1tico)* fácilmente utilizando la librería [SymPy](https://www.sympy.org/es/), la cual nos proporciona el objeto `Limit` para representarlos en [Python](https://www.python.org/). Su sintaxis es la siguiente: `Limit(función, variable, punto)`. Entonces para calcular el límite de $f(x)$ cuando $x$ tiende a 0, debemos escribir:
#
# `Limit(f(x), x, 0)`
#
# Lo utilizamos de la siguiente forma:

# %%
from sympy.interactive import printing
from sympy import Limit, limit, Symbol, S

# imprimir con notación matemática.
printing.init_printing(use_latex='mathjax') 

x = Symbol('x') # Creando el simbolo x.
Limit(x**2 - x + 2, x, 2) # Creando el objeto Limit
# Out:
#      ⎛ 2        ⎞
#  lim ⎝x  - x + 2⎠
# x─→2⁺

# %%
# Resolviendo el Limite con el metodo doit()
Limit(x**2 - x + 2, x, 2).doit()
# Out:
# 4

# %%
# Resolviendo limite 1/x cuando x tiende a infinito
Limit(1/x, x, S.Infinity)
# Out:
#     1
# lim ─
# x─→∞x

# %%
Limit(1/x, x, S.Infinity).doit()
# Out:
# 0

# %% [markdown]
# Como vemos, primero creamos el símbolo para representar a la variable x utilizando el objeto `Symbol`, y luego creamos nuestro límite utilizando el objeto `Limit`. Por último para resolver el límite, simplemente llamamos al método `doit()` sobre el objeto `Limit` que acabamos de crear. También podemos calcular los *[Límites](https://es.wikipedia.org/wiki/L%C3%ADmite_matem%C3%A1tico)* de valores de $x$ que tiendan hacia el [infinito](https://es.wikipedia.org/wiki/Infinito) utilizando la *clase* especial `S.Infinity` que nos proporciona [SymPy](https://www.sympy.org/es/).
#
# ## Hora de hacer ejercicios de funciones y límites...
